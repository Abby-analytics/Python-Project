# %%
2+2
# Out:
# 4

# %%
'this'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 this
#
# NameError: name 'this' is not defined

# %%
2+2
3*3

# %%
print(2+2)
3*3

# %% [markdown]
# **This is a comment**

# %%
# !ls

# %%
# %timeit [i**2 for i in range(1000)]
# Out:
# 134 μs ± 8.08 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
salary = 1000000

# %%
salary

# %%
base_salary = 100000
bonus_rate = 0.1

# %%
total_salary = (base_salary) * (1 + bonus_rate)

# %%
total_salary

# %%
company_name = 'DataWiz Inc'

# %%
company_name

# %%
job_wfh = True

# %%
job_wfh

# %%
job_id = 101
job_title = 'Data Analyst'
job_salary = 125000

# %%
print("Data Job Description")
print("++++++++++++++++++++")
print("Job_id:      ", job_id)
print("Company Name:", company_name)
print("Job Title:   ", job_title)
print("Salary:      ", salary)
print("WFH:         ", job_wfh)
# Out:
# Data Job Description
# ++++++++++++++++++++
# Job_id:       101
# Company Name: DataWiz Inc
# Job Title:    Data Analyst
# Salary:       1000000
# WFH:          True

# %%
help(str)

# %%
Job_title = "Data Analyst"
Job_location = "Nigeria"
Job_Salary = 90000

# %%
print(f"JOB:            {Job_title}\nlocation:   {Job_location}\nsalary:    ${Job_Salary:,.0f}")

# %%
def display_info(title, location, salary):
    return print(f"JOB:            {Job_title}\nlocation:   {Job_location}\nsalary:    ${Job_Salary:,.0f}")

# %%
display_info(Job_title, Job_location, Job_Salary)

# %%
'Data ' + 'Nerd'

# %%
skill = "Python"

# %%
Job_title

# %%
Job_title.replace('a', 'o', 2)

# %%
Job_title

# %%
salary_kelly = 60000
salary_luke = 40000

# %%
salary_kelly == salary_luke

# %%
1 == 1

# %%
if(salary_kelly > salary_luke):
    print("kelly is more paid than luke")
else:
    print("luke is more paid than kelly")

# %%
if True:
    print("What's up data nerds")

# %%
applicant_skill = 'SQL'

# skill required for the job posting
job_skill = 'SQL'

# %%
if job_skill == applicant_skill:
    print('skills match')

# %%
applicant_skill = 'python'
job_skill = 'SQL'
years_experience = 3
if job_skill == applicant_skill:
    print('skill match')
elif years_experience >= 5:
    print('Enough experience, No SQL')
elif applicant_skill == 'python':
    print('This applicant should know SQL')
else:
    print('No Experience or Skill')

# %%
# (...) and (pass) means python should excuse the code for now and it's not complete

# %%
job_skills = ['sql', 'tableau', 'excel']

# %%
job_skills

# %%
job_skills.append('python')

# %%
len(job_skills)

# %%
job_skills[1]

# %%
job_skills.pop(3)

# %%
job_skills.insert(2,'python')

# %%
job_skills[0:4]

# %%
luke_skills = ['python', 'bigquery', 'r']
kelly_skills = ['python', 'sql', 'looker']

all_skills = luke_skills + kelly_skills

# %%
all_skills

# %%
all_skills[-3:]

# %%
skill1, skill2, skill3, skill4, skill5, skill6 = all_skills

# %%
print(skill1)
print(skill5)

# %%
while False:
    print("Data Nerds")

# %%
count = 1
while count <5:
    print(count)
    count +=1

# %%
years_experience = {
    'luke': 3,
    'kelly': 6,
    'ken': 4,
    'alex': 3,
    'Mary': 7,
}

# %%
for person, vale in years_experience.items():
    print(person, 'has', vale, 'years of experience')

# %%
years = 0
index = 0

years_list = list(years_experience.items())

while years < 5:
    key, years = years_list[index]
    if years >= 5:
        print(key,years)
    index += 1

# %%
years_list

# %%
years_experience

# %%
for key, value in years_experience.items():
    if value > 5:
        print (key, value)

# %%
for _ in range(years_experience.items()):
    print(_)

# %%
number = [0, 1, 2, 3, 4, 5]

# %%
for number in number:
    print(number)

# %%
numbers = []

for number in range(100):
    numbers.append(number)

# %%
number

# %%
numbers

# %%
numbers = [x for x in range(100)] 

numbers

# %%
from datasets import load_dataset

ds = load_dataset("lukebarousse/data_jobs")

# %%
even_numbers = [ev for ev in numbers if ev % 2 == 0]
print(even_numbers)

# %%
job_list = [
    # Data Analytics & Business Intelligence
    "Data Analyst",
    "Business Intelligence (BI) Analyst",
    "Reporting Analyst",
    "Marketing Data Analyst",
    "Operations Analyst",
    "Financial Data Analyst",
    "Risk Analyst",
    "Healthcare Data Analyst",
    "Product Analyst",
    "Customer Insights Analyst",
    "Revenue Analyst",
    "Sales Data Analyst",
    "People (HR) Data Analyst",
    "Sports Data Analyst",
    "Fraud Analyst",

    # Data Science & Advanced Analytics
    "Data Scientist",
    "Machine Learning Engineer",
    "AI Research Scientist",
    "Applied Scientist",
    "Research Data Scientist",
    "NLP Engineer",
    "Computer Vision Scientist",
    "Deep Learning Engineer",
    "Predictive Modeler",
    "Behavioral Data Scientist",
    "Econometrician",
    "Quantitative Analyst (Quant)",

    # Data Engineering & Infrastructure
    "Data Engineer",
    "Big Data Engineer",
    "Data Pipeline Developer",
    "Cloud Data Engineer",
    "Hadoop Developer",
    "ETL Developer",
    "Data Integration Engineer",
    "Spark Developer",
    "DataOps Engineer",
    "Data Platform Engineer",
    "Streaming Data Engineer",
    "Snowflake Developer",

    # Data Architecture & Management
    "Data Architect",
    "Enterprise Data Architect",
    "Cloud Data Architect",
    "Information Architect",
    "Data Warehouse Architect",
    "Database Administrator (DBA)",
    "Data Steward",
    "Metadata Manager",
    "Master Data Management (MDM) Specialist",
    "Database Engineer",

    # Data Governance & Quality
    "Data Governance Specialist",
    "Data Quality Analyst",
    "Data Compliance Analyst",
    "Data Privacy Officer",
    "Information Governance Analyst",
    "Regulatory Data Analyst",
    "Audit Data Analyst",
    "Data Security Analyst",

    # Specialized Data Roles
    "Geospatial Data Analyst",
    "Bioinformatics Data Scientist",
    "Sports Statistician",
    "Social Data Analyst",
    "Urban Data Scientist",
    "Education Data Analyst",
    "Government Data Officer",
    "Environmental Data Scientist",
    "Scientific Computing Specialist",

    # Tools and Platform-Specific Roles
    "Power BI Developer",
    "Tableau Developer",
    "Looker Developer",
    "QlikView Analyst",
    "SAS Programmer",
    "R Programmer",
    "Python Data Developer",
    "SQL Developer",
    "Excel Data Analyst",
    "AWS Data Specialist",
    "Azure Data Engineer",
    "GCP Data Specialist"
]

# %%
analyst_list = [job for job in job_list if "Data Analyst" in job]

analyst_list

# %%
len(job_list)
# Out:
# 78

# %%
job_roles =[
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
    {'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
    {'role': 'Machine Learining Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
    {'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
    {'role': 'Business Intellgence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power Bi', 'Excel']},
    {'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
    {'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
    {'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
    {'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
    {'role': 'statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']},
]

# %%
my_skills = ['Python', 'SQL', 'Excel']

# %%
for job in job_roles:
    print(job['skills'])

# %%
for job in job_roles:
    for skill in my_skills:
        print(skill)
        print(job['skills'])

# %%
for job in job_roles:
    for skill in my_skills:
        if skill in job['skills']:
            print(skill)
            print(job['skills'])

# %%
new_roles = []
for job in job_roles:
    qualified = True

    for skill in my_skills:
        if skill not in job['skills']:
            qualified = False
            break

    if qualified:
        new_roles.append(job['role'])

new_roles

# %%
 data_salaries = [95000, 100000, 85000, 97000, 140000]

# %%
min(data_salaries)

# %%
sorted(data_salaries)

# %%
base_salary = 100000
bonus_rate = 0.1


def calculate_salary(base_salary, bonus_rate=.1):

    total_salary = base_salary * (1 + bonus_rate)
    return total_salary

# %%
calculate_salary(base_salary)

# %%
calculate_salary(150000)

# %%
new_salary = 300000
rate_1 = 0.1

calculate_salary(new_salary, rate_1)

# %% [markdown]
# ### lamda fuctions more advance

# %%
mul_two = lambda x:x*2

# %%
mul_two(2)

# %%
(lambda x:x*2)(9)

# %%
(lambda x, y: x*2 + y)(6,7)

# %%
salary_list = [100000, 200000, 150000, 120000, 80000, 750000]
# calculate Total salaries of base_salary * (1+ bonus_rate)
#def calculate_salary(base_salary, bonus_rate=.1):

    #total_salary = base_salary * (1 + bonus_rate)
    #return total_salary
total_salary_list = [(lambda x: x* (1 + 0.1))(salary) for salary in salary_list]

total_salary_list

# %%
jobs_data = [
    {'job_title': 'Data Scientist', 'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Analyst', 'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False},
]

# %%
help(filter)

# %%
list(filter(lambda job: job['remote'] and "Python" in job['job_skills'], jobs_data))

# %%
# modules

# %%
import my_modules

my_modules.skill("Python")

# %%
from job_analyser import *

calculate_salary(10000)

calculate_bonus(110000, 100000)

# %%
 help(calculate_salary)

# %%
salary_list = [98000, 101000, 102000, 99000, 97000]

# %%
from statistics import mean, mode, median

print(mean(salary_list))
print(median(salary_list))
print(mode(salary_list))

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Scikit-learn']", 'job_date': '2023-06-01'},
    {'job_title': 'Data Analyst', 'job_skills': "['Excel', 'SQL', 'Tableau']", 'job_date': '2023-06-15'},
    {'job_title': 'AI Research Scientist', 'job_skills': "['Python', 'Deep Learning', 'PyTorch']", 'job_date': '2023-07-03'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'ETL', 'Spark']", 'job_date': '2023-07-22'},
    {'job_title': 'Business Intelligence Analyst', 'job_skills': "['Power BI', 'SQL', 'Data Modeling']", 'job_date': '2023-08-10'},
    {'job_title': 'NLP Engineer', 'job_skills': "['Python', 'NLP', 'Transformers']", 'job_date': '2023-09-05'},
    {'job_title': 'Statistical Analyst', 'job_skills': "['R', 'Statistics', 'SQL']", 'job_date': '2023-09-18'},
    {'job_title': 'Computer Vision Engineer', 'job_skills': "['Python', 'OpenCV', 'Deep Learning']", 'job_date': '2023-10-01'},
    {'job_title': 'Quantitative Analyst', 'job_skills': "['Python', 'Pandas', 'Finance']", 'job_date': '2023-10-22'},
    {'job_title': 'Data Science Intern', 'job_skills': "['Python', 'Jupyter', 'Data Cleaning']", 'job_date': '2023-11-10'},
    {'job_title': 'Data Product Manager', 'job_skills': "['Data Strategy', 'SQL', 'Communication']", 'job_date': '2023-11-28'},
    {'job_title': 'ETL Developer', 'job_skills': "['ETL', 'SQL', 'Airflow']", 'job_date': '2023-12-05'},
    {'job_title': 'Deep Learning Specialist', 'job_skills': "['Keras', 'Python', 'CNN']", 'job_date': '2024-01-11'},
    {'job_title': 'Big Data Analyst', 'job_skills': "['Hadoop', 'Spark', 'SQL']", 'job_date': '2024-02-01'}
]

# %%
from datetime import datetime

# %%
datetime.now

# %%
data_science_jobs[0]['job_date']

# %%
from datetime import datetime
import ast
for job in data_science_jobs:
    job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')
    job['job_skills'] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs

# %%
# !pip install pandas

# %%
# !pip list

# %%
# !pip install pyjokes

# %%
class BaseSalary:
    def __init__(self, base_salary, bonus_rate=0.1, symbol="$"):
        self.base_salary = base_salary
        self.bonus_rate = bonus_rate
        self.symbol = symbol
        self.total_salary = base_salary * (1 + bonus_rate)
        self.bonus = self.total_salary - self.base_salary

    def __repr__(self):
        return f'{self.symbol}{self.base_salary:,.0f}'
        
    def calculate_salary(self):
        return f'{self.symbol}{self.total_salary:,.0f}'

    def calculate_bonus(self):
        return f'{self.symbol}{self.bonus:,.0f}'

# %%
salary = BaseSalary(100000)

salary
# Out:
# $100,000

# %%
salary.calculate_salary()
# Out:
# '$110,000'

# %%
salary.calculate_bonus()
# Out:
# '$10,000'

# %%
#numpy

# %%
import random

salary_list = [random.randint(50000,100000) for ev in range(10_000_000)]

# %%
salary_list

# %% [raw]
# Print(len(salary_list))

# %%
salary_list

# %%
# %%timeit

import statistics

statistics.mean(salary_list)
# Out:
# 3.74 s ± 120 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit

np.mean(salary_list)
# Out:
# 573 ms ± 32.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
my_array = np.array([1, 2, 3, 4, 5])

# %%
my_array.mean()
# Out:
# 3.0

# %%
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'AI Engineer'])

base_salaries = np.array([60000, 80000, 75000, 90000, np.nan])

bonus_rate = np.array([.05, .1, .08, .12, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rate)
total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.,     nan])

# %%
np.nanmean(total_salaries)
# Out:
# 83200.0

# %%
type(np.nan)
# Out:
# float

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/user/Documents/CUSTOMER TABLE.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        CustomerID Gender MaritalStatus        YearlyIncome   Revenue  \
# 0           10002      F       Married              0-25000  3953.99
# 1           10003      F       Married              0-25000  3953.99
# 2           10004      F       Married              0-25000  3953.99
# 3           10005      F       Married              0-25000  3953.99
# 4           10006      F       Married              0-25000  3953.99
# ...           ...    ...           ...                  ...      ...
# 17417       27419      M        Single  greater than 100000  2644.33
# 17418       27420      M        Single  greater than 100000  2658.63
# 17419       27421      M        Single  greater than 100000  2623.23
# 17420       27422      M        Single  greater than 100000    24.29
# 17421       27423      M        Single  greater than 100000    77.34
#
#        OrderDate         Country   BirthDate Lastname    Firstname
# 0       6/2/2011       Australia   8/11/1957     Raje       Kelsey
# ...

# %%
df['MaritalStatus'][17421]
# Out:
# 'Single'

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\user\.cache\huggingface\datasets\lukebarousse___data_jobs\default\0.0.0\ed776e5a0a8c40ea9d5efbd800772ae52e140f3e (last modified on Tue Jun 10 20:06:45 2025).

# %%
df = dataset['train'].to_pandas()

# %%
 df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.iloc[90]
# Out:
# job_title_short                                             Data Scientist
# job_title                                                   Data Scientist
# job_location                                                     Australia
# job_via                                                via BeBee Australia
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                  Australia
# job_posted_date                                        2023-11-25 13:12:03
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                      Australia
# salary_rate                                                           None
# ...

# %%
df[['job_title_short', 'job_title', 'job_via']].iloc[90:110]
# Out:
#           job_title_short                                          job_title  \
# 90         Data Scientist                                     Data Scientist
# 91         Data Scientist                                     Data Scientist
# 92          Data Engineer            Remote - Data Engineer - Permanent - W2
# 93           Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94          Data Engineer                   Data Engineer - Cloud Operations
# 95          Data Engineer                                      Data Engineer
# 96          Data Engineer                                      Data Engineer
# 97           Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98   Senior Data Engineer                         Senior Data Engineer (AWS)
# 99          Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
# 100        Data Scientist            Data Scientist, Risk Data Mining - USDS
# ...

# %%
len(df)
# Out:
# 785741

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.shape
# Out:
# (785741, 17)

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
len(df.job_title_short.unique())
# Out:
# 10

# %%
df.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna())]
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
import pandas as pd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df.sort_values('job_posted_date', inplace=True)

# %%
df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df.drop(labels='salary_hour_avg', axis = 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(['job_title_short', 'job_country'])[['salary_year_avg', 'salary_hour_avg']].median()
# Out:
#                                salary_year_avg  salary_hour_avg
# job_title_short   job_country
# Business Analyst  Afghanistan              NaN              NaN
#                   Albania                  NaN              NaN
#                   Algeria                  NaN              NaN
#                   Angola                   NaN              NaN
#                   Argentina            71100.0              NaN
# ...                                        ...              ...
# Software Engineer Venezuela                NaN              NaN
#                   Vietnam              53600.0              NaN
#                   Yemen                    NaN              NaN
#                   Zambia                   NaN              NaN
#                   Zimbabwe                 NaN              NaN
#
# [1387 rows x 2 columns]

# %%
df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].agg(['min', 'max', 'median'])
# Out:
#                           salary_year_avg                     salary_hour_avg  \
#                                       min       max    median             min
# job_title_short
# Business Analyst                  16500.0  387460.0   85000.0          10.835
# Cloud Engineer                    42000.0  280000.0   90000.0          18.500
# Data Analyst                      25000.0  650000.0   90000.0           8.000
# Data Engineer                     15000.0  525000.0  125000.0           8.000
# Data Scientist                    27000.0  960000.0  127500.0           8.000
# Machine Learning Engineer         30000.0  325000.0  106415.0          10.000
# Senior Data Analyst               30000.0  425000.0  111175.0          13.000
# Senior Data Engineer              35000.0  425000.0  147500.0          12.500
# Senior Data Scientist             45000.0  890000.0  155500.0          17.500
# Software Engineer                 28000.0  375000.0   99150.0          11.000
#
#
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
import pandas as pd

# %%
len(df['job_country'].unique())
# Out:
# 161

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Australia']).value_counts()
# Out:
# job_country
# False    772786
# True      12955
# Name: count, dtype: int64

# %%
us_jobs = df[df['job_country'] == 'United States']

# %%
us_jobs
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

# %%
us_jobs
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
us_jobs.groupby('job_title_short').count()
# Out:
#                            job_title  job_location  job_via  \
# job_title_short
# Business Analyst                 431           425      431
# Cloud Engineer                    20            20       20
# Data Analyst                    4350          4285     4350
# Data Engineer                   2915          2869     2915
# Data Scientist                  4553          4498     4553
# Machine Learning Engineer        128           128      128
# Senior Data Analyst              913           903      913
# Senior Data Engineer            1058          1041     1058
# Senior Data Scientist           1241          1220     1241
# Software Engineer                157           155      157
#
#                            job_schedule_type  job_work_from_home  \
# job_title_short
# Business Analyst                         430                 431
# Cloud Engineer                            19                  20
# Data Analyst                            4342                4350
# ...

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max', 'count']).sort_values('median', ascending=False)
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      155000.0  55000.0  475000.0   1241
# Machine Learning Engineer  150000.0  44408.5  315000.0    128
# Senior Data Engineer       150000.0  45000.0  375000.0   1058
# Data Scientist             130000.0  30000.0  960000.0   4553
# Software Engineer          130000.0  48982.0  375000.0    157
# Data Engineer              125000.0  23496.0  525000.0   2915
# Cloud Engineer             116100.0  42000.0  221844.0     20
# Senior Data Analyst        110000.0  35360.0  425000.0    913
# Business Analyst            90000.0  35000.0  387460.0    431
# Data Analyst                90000.0  25000.0  375000.0   4350

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ------------------
# aext-assistant                    4.20.0
# aext-assistant-server             4.20.0
# aext-core                         4.20.0
# aext-core-server                  4.20.0
# aext_environments_server          4.20.0
# aext-panels                       4.20.0
# aext-panels-server                4.20.0
# aext-project-filebrowser-server   4.20.0
# aext-share-notebook               4.20.0
# aext-share-notebook-server        4.20.0
# aext-shared                       4.20.0
# aext-toolbox                      4.20.0
# aiobotocore                       2.12.3
# aiohappyeyeballs                  2.4.0
# aiohttp                           3.10.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# alembic                           1.13.3
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# ...

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x,y)

# %%
x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]

plt.plot(x,y)
plt.show()

# %%
df.job_posted_date.head()
# Out:
# 0   2023-06-16 13:44:15
# 1   2023-01-14 13:18:07
# 2   2023-10-10 13:14:55
# 3   2023-07-04 13:01:41
# 4   2023-08-07 14:29:36
# Name: job_posted_date, dtype: datetime64[ns]

# %%
plt.plot(df.job_posted_date, df.job_posted_date)

# %%
date_counts = df.job_posted_date.value_counts()

# %%
date_counts = date_counts.sort_index()

# %%
plt.plot(date_counts.index, date_counts)

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
monthly_counts = df.job_posted_month.value_counts()

monthly_counts = monthly_counts.sort_index()

monthly_counts
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
plt.plot(monthly_counts.index, monthly_counts)

# %%
job_counts = df.job_title_short.value_counts()

# %%
job_counts = job_counts.sort_values(ascending=False)
plt.barh(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
job_counts
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
plt.bar(job_counts.index, job_counts)
plt.ylabel('Count of Job Posting')
plt.xticks(rotation=45, ha='right')
plt.title('Posting by Job Title')
# Out:
# Text(0.5, 1.0, 'Posting by Job Title')

# %%
job_counts.plot(kind='bar')
plt.xlabel('')
plt.ylabel('Count of Job Posting')
plt.xticks(rotation=45, ha='right')
plt.title('Posting by Job Title')
# Out:
# Text(0.5, 1.0, 'Posting by Job Title')

# %%
df.plot(x='job_posted_month', y='salary_year_avg', kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
df.groupby('job_title_short')['salary_year_avg'].median().sort_values()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Software Engineer             99150.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Name: salary_year_avg, dtype: float64

# %%
job_salary = df.groupby('job_title_short')['salary_year_avg'].mean().sort_values(ascending=True)

# %%
job_salary.plot(kind='barh')
plt.xlabel('salary (USD)')
plt.ylabel('')
plt.title('Median Salary by Job Title')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
